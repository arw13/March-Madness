# %% [markdown]
# # Keras MLP -> best Log Loss 0.555
# ## Overview ##
# This kernel uses seeding and relative seeding with an MLP network. Spread on loss was very small, so kfold not necessary

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from time import localtime
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, BatchNormalization
from keras import regularizers
from keras.callbacks import EarlyStopping, TensorBoard, ProgbarLogger
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold




# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../NCAA"]).decode("utf8"))

# Any results you write to the current directory are saved as output.
# Out:
# Data
# GiantKillerInfo.txt
# KaggleKernelwSeeds.ipynb
# KerasBinaryClassifier_Intro.ipynb
# KerasMLP_only2003.csv
# KerasMLP_onlyBPI_2009-2013.csv
# KerasMLP_onlyseed.csv
# KerasMLP_onlyseeds.csv
# KerasMLP_RankAndSeeds.ipynb
# KerasMLP_Rank_Kfold.ipynb
# KerasMLP_RankSeedsYear_1_2.csv
# KerasMLP_RankSeedsYear_1.csv
# KerasMLP_RankSeedsYear.csv
# KerasMLP_RanksKfold.ipynb
# KerasMLP_SeedsandYear_1.csv
# KerasMLP_SeedsandYear.csv
# KerasMLP_SeedsOnly.ipynb
# KerasMLP_SeedswithTB.ipynb
# logreg_withseedtoo.csv
# logs
# MasseyOrdinalsExp.ipynb
# MLP_first_go.csv
# MLP_with_seeds.csv
# sonar.csv
# SVM_first_go.csv
# Tensorflow.ipynb

# %% [markdown]
# ### Lock Random Seed

# %%
seed = 13
np.random.seed(seed)

# %% [markdown]
# ### Load Training data

# %%
data_dir = '../NCAA/Data/'
df_seeds = pd.read_csv(data_dir + 'NCAATourneySeeds.csv')
df_tour = pd.read_csv(data_dir + 'NCAATourneyCompactResults.csv')
df_tour.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT
# 0    1985     136     1116      63     1234      54    N      0
# 1    1985     136     1120      59     1345      58    N      0
# 2    1985     136     1207      68     1250      43    N      0
# 3    1985     136     1229      58     1425      55    N      0
# 4    1985     136     1242      49     1325      38    N      0

# %% [markdown]
# Incorporate Massey Ordinals - MAS, SAG, POM

# %%
#Load Data
df_rank = pd.read_csv(data_dir+ 'MasseyOrdinals.csv')
#Choose Latest Ranking 
df_rank = df_rank[df_rank.RankingDayNum>=133]
df_rank = df_rank[df_rank.Season>=2010]

#Selectr rankings of interest and make each ranking system ranking into a separate column
df_merge = pd.merge(df_rank.loc[df_rank['SystemName']=='MAS'],
                    df_rank.loc[df_rank['SystemName']=='SAG'], how='left', 
                    on=['Season', 'TeamID', 'RankingDayNum'])
df_rank = pd.merge(left=df_merge, right=df_rank.loc[df_rank['SystemName']=='POM'], 
                  how='left', on=['Season', 'TeamID', 'RankingDayNum'] )

# %%
# Drop
df_rank.drop(labels=['SystemName_x', 'SystemName_y', 'SystemName','RankingDayNum'], inplace=True, axis =1)
df_rank.rename(columns={'OrdinalRank_x':'MAS', 'OrdinalRank_y':'SAG', 'OrdinalRank':'POM'}, inplace=True)

df_rank.head()
# Out:
#    Season  TeamID  MAS  SAG  POM
# 0    2010    1102  239  237  246
# 1    2010    1103   89  105  119
# 2    2010    1104   79   72   64
# 3    2010    1105  329  337  336
# 4    2010    1106  276  300  302

# %% [markdown]
# Cut seasons prior to Max Ranking date

# %%
df_seeds = df_seeds[df_seeds.Season>=min(df_rank.Season) ]
df_seeds = df_seeds[ df_seeds.Season<=max(df_rank.Season)]
df_tour = df_tour[df_tour.Season>=min(df_rank.Season)]
df_tour = df_tour[ df_tour.Season<=max(df_rank.Season)]
df_tour.head()
# Out:
#       Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT
# 1584    2010     134     1115      61     1457      44    N      0
# 1585    2010     136     1124      68     1358      59    N      0
# 1586    2010     136     1139      77     1431      59    N      0
# 1587    2010     136     1140      99     1196      92    N      2
# 1588    2010     136     1242      90     1250      74    N      0

# %% [markdown]
# Cut off the region identifier from the seed number

# %%
def seed_to_int(seed):
    #Get just the digits from the seeding. Return as int
    s_int = int(seed[1:3])
    return s_int
df_seeds['seed_int'] = df_seeds.Seed.apply(seed_to_int)
df_seeds.drop(columns=['Seed'], inplace=True) # This is the string label

# %%
df_tour.drop(labels=['DayNum', 'WScore', 'LScore','WLoc', 'NumOT'], inplace=True, axis=1)
# df_tour.head()

# %% [markdown]
# Merge the Seeds with their corresponding TeamIDs in the compact results dataframe.

# %%
df_winSeeds = df_seeds.rename(columns={'TeamID':'WTeamID', 'seed_int':'WSeed'})
df_lossSeeds = df_seeds.rename(columns={'TeamID':'LTeamID', 'seed_int':'LSeed'})
df_seeds.head()
# Out:
#       Season  TeamID  seed_int
# 1609    2010    1246         1
# 1610    2010    1452         2
# 1611    2010    1307         3
# 1612    2010    1458         4
# 1613    2010    1396         5

# %%
df_dummy = pd.merge(left=df_tour, right=df_lossSeeds, how='left', on=['Season', 'LTeamID'])
df_dummy.head()
# Out:
#    Season  WTeamID  LTeamID  LSeed
# 0    2010     1115     1457     16
# 1    2010     1124     1358     14
# 2    2010     1139     1431     12
# 3    2010     1140     1196     10
# 4    2010     1242     1250     16

# %%
df_concat = pd.merge(left=df_dummy, right=df_winSeeds, how='left' ,on=['Season', 'WTeamID'])
# df_concat['SeedDiff'] = df_concat.WSeed - df_concat.LSeed
df_concat.head()
# Out:
#    Season  WTeamID  LTeamID  LSeed  WSeed
# 0    2010     1115     1457     16     16
# 1    2010     1124     1358     14      3
# 2    2010     1139     1431     12      5
# 3    2010     1140     1196     10      7
# 4    2010     1242     1250     16      1

# %% [markdown]
# Dataframe with seed, relative seed, and win/loss. Use for training

# %%
df_wins = pd.DataFrame()
df_wins['Seed'] = df_concat['WSeed']
# df_wins['SeedDiff'] = df_concat['SeedDiff']
df_wins['TeamID'] = df_concat['WTeamID']
df_wins['Season'] = df_concat['Season']
df_wins['Result'] = 1
df_wins = pd.merge(left=df_wins, right=df_rank, how='left', on=['Season', 'TeamID'])
df_wins.head()
df_wins.head()
# Out:
#    Seed  TeamID  Season  Result  MAS  SAG  POM
# 0    16    1115    2010       1  232  239  238
# 1     3    1124    2010       1   11    8   12
# 2     5    1139    2010       1   13   22   26
# 3     7    1140    2010       1   14    9    7
# 4     1    1242    2010       1    1    1    2

# %%
df_losses = pd.DataFrame()
df_losses['Seed'] = df_concat['LSeed']
# df_losses['SeedDiff'] = -df_concat['SeedDiff']
df_losses['TeamID'] = df_concat['LTeamID']
df_losses['Season'] = df_concat['Season']
df_losses['Result'] = 0
df_losses = pd.merge(left=df_losses, right=df_rank, how='left',on=['Season', 'TeamID'])
df_losses.head()
# Out:
#    Seed  TeamID  Season  Result  MAS  SAG  POM
# 0    16    1457    2010       0  192  210  212
# 1    14    1358    2010       0   96  106  102
# 2    12    1431    2010       0   28   33   34
# 3    10    1196    2010       0   55   48   49
# 4    16    1250    2010       0  201  204  180

# %%
df_lossesOpp = df_losses.copy()
df_lossesOpp.drop(labels=['Season', 'Result'], inplace=True, axis=1)
new_names = [(i,'Opp'+i) for i in df_lossesOpp.columns.values]
df_lossesOpp.rename(columns = dict(new_names), inplace=True)
df_lossesOpp.head()
# Out:
#    OppSeed  OppTeamID  OppMAS  OppSAG  OppPOM
# 0       16       1457     192     210     212
# 1       14       1358      96     106     102
# 2       12       1431      28      33      34
# 3       10       1196      55      48      49
# 4       16       1250     201     204     180

# %%
df_winsOpp = df_wins.copy()
df_winsOpp.drop(labels=['Season', 'Result'], inplace=True, axis=1)
new_names = [(i,'Opp'+i) for i in df_winsOpp.columns.values]
df_winsOpp.rename(columns = dict(new_names), inplace=True)
df_winsOpp.head()
# Out:
#    OppSeed  OppTeamID  OppMAS  OppSAG  OppPOM
# 0       16       1115     232     239     238
# 1        3       1124      11       8      12
# 2        5       1139      13      22      26
# 3        7       1140      14       9       7
# 4        1       1242       1       1       2

# %%
df_winloss = pd.concat([df_wins, df_lossesOpp], axis=1)

df_losswin = pd.concat([df_losses, df_winsOpp], axis=1)
df_losswin.head()
# Out:
#    Seed  TeamID  Season  Result  MAS  SAG  POM  OppSeed  OppTeamID  OppMAS  \
# 0    16    1457    2010       0  192  210  212       16       1115     232
# 1    14    1358    2010       0   96  106  102        3       1124      11
# 2    12    1431    2010       0   28   33   34        5       1139      13
# 3    10    1196    2010       0   55   48   49        7       1140      14
# 4    16    1250    2010       0  201  204  180        1       1242       1
#
#    OppSAG  OppPOM
# 0     239     238
# 1       8      12
# 2      22      26
# 3       9       7
# 4       1       2

# %%
df_finalData = pd.concat((df_winloss, df_losswin))
results = df_finalData['Result']
df_finalData.drop(labels=['Result'], inplace=True, axis=1)
df_finalData.insert(0, 'Result', results)
df_finalData.head()
# Out:
#    Result  Seed  TeamID  Season  MAS  SAG  POM  OppSeed  OppTeamID  OppMAS  \
# 0       1    16    1115    2010  232  239  238       16       1457     192
# 1       1     3    1124    2010   11    8   12       14       1358      96
# 2       1     5    1139    2010   13   22   26       12       1431      28
# 3       1     7    1140    2010   14    9    7       10       1196      55
# 4       1     1    1242    2010    1    1    2       16       1250     201
#
#    OppSAG  OppPOM
# 0     210     212
# 1     106     102
# 2      33      34
# 3      48      49
# 4     204     180

# %%
df_finalData.isnull().any()
# Out:
# Result       False
# Seed         False
# TeamID       False
# Season       False
# MAS          False
# SAG          False
# POM          False
# OppSeed      False
# OppTeamID    False
# OppMAS       False
# OppSAG       False
# OppPOM       False
# dtype: bool

# %% [markdown]
#  ### Set feature ouput and feature vector, split into training and test

# %%
X = df_finalData.iloc[:,1:]
# Set input_dim
xDim = np.shape(X)[1]
X= X.values.reshape(-1,xDim)

y = df_finalData.Result.values
trainSize = int(np.shape(X)[0]*.8)
x_train, x_test = X[:trainSize, :], X[trainSize:,:]
y_train, y_test = y[:trainSize], y[trainSize:]

print('Feature vector dimension is: %.2f' % xDim)
print(X[:5,:])
# Out:
# Feature vector dimension is: 11.00
# [[  11 1173 2014   52   58   51   10 1390   35   33   36]
#  [   3 1124 2017   15   14   13   11 1425   50   55   61]
#  [  11 1173 2014   52   58   51    1 1196    1    3    3]
#  [  14 1195 2017   92  113  108    3 1199   22   20   19]
#  [   2 1181 2013   11    7    6   15 1107  104  167  147]]

# %% [markdown]
# ## MLP Props
# droput rate, batch size, epoch size

# %%
dropRate = 0.5
numBatch = 5
numEpoch = 25

# %% [markdown]
# ###  MLP Base, 10 Nodes

# %%
# base model
def base10():
    model = Sequential()
    model.name = 'base10'
    model.add(Dense(10, input_dim=xDim, kernel_initializer='normal', activation = 'relu'))
    model.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %% [markdown]
# ### MLP Base 20 Nodes

# %%
# base model
def base20():
    model = Sequential()
    model.name = 'base20'
    model.add(Dense(20, input_dim=xDim, kernel_initializer='normal', activation = 'relu'))
    model.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %% [markdown]
# ### MLP Base 20 Nodes with regularization

# %%
# base model
def base20exp():
    model = Sequential()
    model.name = 'base20'
    model.add(Dense(20, input_dim=xDim, kernel_initializer='normal',activation = 'relu'))
    model.add(Dense(20, input_dim=xDim, kernel_initializer='normal',activation = 'relu'))
    model.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %% [markdown]
# ### Dropout Model
# cut 2/22

# %%
# dropout model
def dropmod():
    model = Sequential()
    model.name = 'dropmod'
    model.add(Dense(10, input_dim=xDim, kernel_initializer='normal',activation = 'relu'))
    model.add(Dropout(dropRate))
    model.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))

    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %% [markdown]
# ### Dense Model
#  cut 2/22

# %%
# model model
def dense():
    model = Sequential()
    model.name='dense'
    model.add(Dense(10, input_dim=xDim, kernel_initializer='normal', activation = 'relu'))
    model.add(Dropout(dropRate))
    model.add(Dense(5, input_dim=xDim, kernel_initializer='normal',  activation = 'relu'))
    model.add(Dropout(dropRate))
    model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %% [markdown]
# ### Denser Model with Dropout

# %%
# dense model
def densedrop():
    model = Sequential()
    model.name = 'densedrop'
    model.add(Dense(10, input_dim=xDim, kernel_initializer='normal', activation = 'relu'))
    model.add(Dropout(dropRate))
    model.add(Dense(5, input_dim=xDim, kernel_initializer='normal',  activation = 'relu'))
    model.add(Dropout(dropRate))
    model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %% [markdown]
# # Fit the Model

# %% [markdown]
# ### Models of Interest

# %%
model = [base20, base20reg]

# %% [markdown]
# ###  StandardScaler

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ###  with scaled data

# %%
# Fit the model
results=[]
for i in range(0,np.size(model)):  
    TB = TensorBoard(log_dir="logs/{}_{}{}".format(str(model[i].__name__), 
                                                   localtime().tm_hour, localtime().tm_min))
    classifier = KerasClassifier(build_fn=model[i], epochs=numEpoch, batch_size=numBatch, verbose=1)
    kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
    cvresults = cross_val_score(classifier, X, y, cv=kfold, scoring='neg_log_loss', verbose=0)
    results.append(cvresults)
#     print("{}: {} ({})".format(model[i].__name__, results.mean(), results.std()))
# Out:
# Epoch 1/25
# 852/852 [==============================] - 0s 407us/step - loss: 0.6539 - acc: 0.6725
# Epoch 2/25
# 852/852 [==============================] - 0s 259us/step - loss: 0.5851 - acc: 0.6948
# Epoch 3/25
# 852/852 [==============================] - 0s 251us/step - loss: 0.5712 - acc: 0.6948
# Epoch 4/25
# 852/852 [==============================] - 0s 278us/step - loss: 0.5692 - acc: 0.7042
# Epoch 5/25
# 852/852 [==============================] - 0s 249us/step - loss: 0.5679 - acc: 0.6948
# Epoch 6/25
# 852/852 [==============================] - 0s 258us/step - loss: 0.5666 - acc: 0.6995
# Epoch 7/25
# 852/852 [==============================] - 0s 231us/step - loss: 0.5660 - acc: 0.6984
# Epoch 8/25
# 852/852 [==============================] - 0s 252us/step - loss: 0.5656 - acc: 0.7007
# Epoch 9/25
# 852/852 [==============================] - 0s 249us/step - loss: 0.5651 - acc: 0.7031
# Epoch 10/25
# 852/852 [==============================] - 0s 242us/step - loss: 0.5641 - acc: 0.6925
# Epoch 11/25
# 852/852 [==============================] - 0s 247us/step - loss: 0.5631 - acc: 0.7066
# Epoch 12/25
# 852/852 [==============================] - 0s 235us/step - loss: 0.5625 - acc: 0.7054
# Epoch 13/25
# 852/852 [==============================] - 0s 231us/step - loss: 0.5629 - acc: 0.7089
# Epoch 14/25
# 852/852 [==============================] - 0s 231us/step - loss: 0.5619 - acc: 0.7089
# Epoch 15/25
# 852/852 [==============================] - 0s 238us/step - loss: 0.5606 - acc: 0.7148
# Epoch 16/25
# 852/852 [==============================] - 0s 227us/step - loss: 0.5602 - acc: 0.7101
# Epoch 17/25
# 852/852 [==============================] - 0s 236us/step - loss: 0.5592 - acc: 0.7136
# Epoch 18/25
# 852/852 [==============================] - 0s 239us/step - loss: 0.5587 - acc: 0.7124
# Epoch 19/25
# 852/852 [==============================] - 0s 232us/step - loss: 0.5583 - acc: 0.7218
# Epoch 20/25
# 852/852 [==============================] - 0s 235us/step - loss: 0.5580 - acc: 0.7136
# Epoch 21/25
# 852/852 [==============================] - 0s 250us/step - loss: 0.5567 - acc: 0.7218
# Epoch 22/25
# 852/852 [==============================] - 0s 234us/step - loss: 0.5565 - acc: 0.7148
# Epoch 23/25
# 852/852 [==============================] - 0s 251us/step - loss: 0.5560 - acc: 0.7124
# Epoch 24/25
# 852/852 [==============================] - 0s 238us/step - loss: 0.5548 - acc: 0.7207
# Epoch 25/25
# 852/852 [==============================] - 0s 234us/step - loss: 0.5548 - acc: 0.7207
# 214/214 [==============================] - 0s 120us/step
# Epoch 1/25
# 852/852 [==============================] - 0s 359us/step - loss: 0.6626 - acc: 0.6502
# Epoch 2/25
# 852/852 [==============================] - 0s 247us/step - loss: 0.5865 - acc: 0.6948
# Epoch 3/25
# 852/852 [==============================] - 0s 233us/step - loss: 0.5720 - acc: 0.6925
# Epoch 4/25
# 852/852 [==============================] - 0s 250us/step - loss: 0.5708 - acc: 0.6995
# Epoch 5/25
# 852/852 [==============================] - 0s 243us/step - loss: 0.5694 - acc: 0.6984
# Epoch 6/25
# 852/852 [==============================] - 0s 248us/step - loss: 0.5685 - acc: 0.7031
# Epoch 7/25
# 852/852 [==============================] - 0s 233us/step - loss: 0.5675 - acc: 0.7031
# Epoch 8/25
# 852/852 [==============================] - 0s 237us/step - loss: 0.5682 - acc: 0.7019
# Epoch 9/25
# 852/852 [==============================] - 0s 237us/step - loss: 0.5666 - acc: 0.7042
# Epoch 10/25
# 852/852 [==============================] - 0s 238us/step - loss: 0.5656 - acc: 0.7066
# Epoch 11/25
# 852/852 [==============================] - 0s 240us/step - loss: 0.5657 - acc: 0.7031
# Epoch 12/25
# 852/852 [==============================] - 0s 236us/step - loss: 0.5653 - acc: 0.7066
# Epoch 13/25
# 852/852 [==============================] - 0s 238us/step - loss: 0.5653 - acc: 0.7007
# Epoch 14/25
# 852/852 [==============================] - 0s 242us/step - loss: 0.5647 - acc: 0.7042
# Epoch 15/25
# 852/852 [==============================] - 0s 243us/step - loss: 0.5638 - acc: 0.7124
# Epoch 16/25
# 852/852 [==============================] - 0s 238us/step - loss: 0.5629 - acc: 0.7101
# Epoch 17/25
# 852/852 [==============================] - 0s 246us/step - loss: 0.5630 - acc: 0.7077
# Epoch 18/25
# 852/852 [==============================] - 0s 244us/step - loss: 0.5625 - acc: 0.7077
# Epoch 19/25
# 852/852 [==============================] - 0s 247us/step - loss: 0.5629 - acc: 0.7136
# Epoch 20/25
# 852/852 [==============================] - 0s 244us/step - loss: 0.5624 - acc: 0.7136
# Epoch 21/25
# 852/852 [==============================] - 0s 241us/step - loss: 0.5609 - acc: 0.7207
# Epoch 22/25
# 852/852 [==============================] - 0s 242us/step - loss: 0.5617 - acc: 0.7136
# Epoch 23/25
# 852/852 [==============================] - 0s 242us/step - loss: 0.5612 - acc: 0.7101
# Epoch 24/25
# 852/852 [==============================] - 0s 234us/step - loss: 0.5604 - acc: 0.7148
# Epoch 25/25
# 852/852 [==============================] - 0s 247us/step - loss: 0.5612 - acc: 0.7183
# 214/214 [==============================] - 0s 158us/step
# Epoch 1/25
# 852/852 [==============================] - 0s 377us/step - loss: 0.6468 - acc: 0.6948
# Epoch 2/25
# 852/852 [==============================] - 0s 255us/step - loss: 0.5648 - acc: 0.7136
# Epoch 3/25
# 852/852 [==============================] - 0s 247us/step - loss: 0.5571 - acc: 0.7101
# Epoch 4/25
# 852/852 [==============================] - 0s 240us/step - loss: 0.5544 - acc: 0.7171
# Epoch 5/25
# 852/852 [==============================] - 0s 241us/step - loss: 0.5542 - acc: 0.7066
# Epoch 6/25
# 852/852 [==============================] - 0s 235us/step - loss: 0.5519 - acc: 0.7124
# Epoch 7/25
# 852/852 [==============================] - 0s 252us/step - loss: 0.5509 - acc: 0.7171
# Epoch 8/25
# 852/852 [==============================] - 0s 243us/step - loss: 0.5509 - acc: 0.7160
# Epoch 9/25
# 852/852 [==============================] - 0s 242us/step - loss: 0.5497 - acc: 0.7207
# Epoch 10/25
# 852/852 [==============================] - 0s 253us/step - loss: 0.5487 - acc: 0.7218
# Epoch 11/25
# 852/852 [==============================] - 0s 246us/step - loss: 0.5487 - acc: 0.7254
# Epoch 12/25
# 852/852 [==============================] - 0s 251us/step - loss: 0.5476 - acc: 0.7254
# Epoch 13/25
# 852/852 [==============================] - 0s 239us/step - loss: 0.5473 - acc: 0.7183
# Epoch 14/25
# 852/852 [==============================] - 0s 242us/step - loss: 0.5463 - acc: 0.7265
# Epoch 15/25
# 852/852 [==============================] - 0s 243us/step - loss: 0.5455 - acc: 0.7230
# Epoch 16/25
# 852/852 [==============================] - 0s 245us/step - loss: 0.5448 - acc: 0.7289
# Epoch 17/25
# 852/852 [==============================] - 0s 243us/step - loss: 0.5449 - acc: 0.7312
# Epoch 18/25
# 852/852 [==============================] - 0s 244us/step - loss: 0.5447 - acc: 0.7207
# Epoch 19/25
# 852/852 [==============================] - 0s 248us/step - loss: 0.5434 - acc: 0.7277
# Epoch 20/25
# 852/852 [==============================] - 0s 243us/step - loss: 0.5433 - acc: 0.7336
# Epoch 21/25
# 852/852 [==============================] - 0s 242us/step - loss: 0.5424 - acc: 0.7300
# Epoch 22/25
# 852/852 [==============================] - 0s 248us/step - loss: 0.5423 - acc: 0.7289
# Epoch 23/25
# 852/852 [==============================] - 0s 237us/step - loss: 0.5417 - acc: 0.7300
# Epoch 24/25
# 852/852 [==============================] - 0s 243us/step - loss: 0.5409 - acc: 0.7347
# Epoch 25/25
# 852/852 [==============================] - 0s 237us/step - loss: 0.5412 - acc: 0.7359
# 214/214 [==============================] - 0s 198us/step
# Epoch 1/25
# 854/854 [==============================] - 0s 395us/step - loss: 0.6476 - acc: 0.6698
# Epoch 2/25
# 854/854 [==============================] - 0s 233us/step - loss: 0.5657 - acc: 0.7143
# Epoch 3/25
# 854/854 [==============================] - 0s 248us/step - loss: 0.5517 - acc: 0.7096
# Epoch 4/25
# 854/854 [==============================] - 0s 243us/step - loss: 0.5494 - acc: 0.7213
# Epoch 5/25
# 854/854 [==============================] - 0s 244us/step - loss: 0.5484 - acc: 0.7108
# Epoch 6/25
# 854/854 [==============================] - 0s 248us/step - loss: 0.5486 - acc: 0.7213
# Epoch 7/25
# 854/854 [==============================] - 0s 242us/step - loss: 0.5469 - acc: 0.7225
# Epoch 8/25
# 854/854 [==============================] - 0s 238us/step - loss: 0.5458 - acc: 0.7272
# Epoch 9/25
# 854/854 [==============================] - 0s 236us/step - loss: 0.5458 - acc: 0.7319
# Epoch 10/25
# 854/854 [==============================] - 0s 235us/step - loss: 0.5445 - acc: 0.7237
# Epoch 11/25
# 854/854 [==============================] - 0s 229us/step - loss: 0.5439 - acc: 0.7272
# Epoch 12/25
# 854/854 [==============================] - 0s 230us/step - loss: 0.5438 - acc: 0.7237
# Epoch 13/25
# 854/854 [==============================] - 0s 232us/step - loss: 0.5428 - acc: 0.7295
# Epoch 14/25
# 854/854 [==============================] - 0s 231us/step - loss: 0.5422 - acc: 0.7307
# Epoch 15/25
# 854/854 [==============================] - 0s 228us/step - loss: 0.5418 - acc: 0.7260
# Epoch 16/25
# 854/854 [==============================] - 0s 226us/step - loss: 0.5412 - acc: 0.7354
# Epoch 17/25
# 854/854 [==============================] - 0s 230us/step - loss: 0.5406 - acc: 0.7342
# Epoch 18/25
# 854/854 [==============================] - 0s 242us/step - loss: 0.5400 - acc: 0.7354
# Epoch 19/25
# 854/854 [==============================] - 0s 235us/step - loss: 0.5395 - acc: 0.7330
# Epoch 20/25
# 854/854 [==============================] - 0s 239us/step - loss: 0.5402 - acc: 0.7365
# Epoch 21/25
# 854/854 [==============================] - 0s 229us/step - loss: 0.5388 - acc: 0.7342
# Epoch 22/25
# 854/854 [==============================] - 0s 229us/step - loss: 0.5386 - acc: 0.7342
# Epoch 23/25
# 854/854 [==============================] - 0s 234us/step - loss: 0.5376 - acc: 0.7365
# Epoch 24/25
# 854/854 [==============================] - 0s 236us/step - loss: 0.5381 - acc: 0.7342
# Epoch 25/25
# 854/854 [==============================] - 0s 232us/step - loss: 0.5377 - acc: 0.7354
# 212/212 [==============================] - 0s 246us/step
# Epoch 1/25
# 854/854 [==============================] - 0s 414us/step - loss: 0.6563 - acc: 0.6639
# Epoch 2/25
# 854/854 [==============================] - 0s 235us/step - loss: 0.5901 - acc: 0.6874
# Epoch 3/25
# 854/854 [==============================] - 0s 229us/step - loss: 0.5785 - acc: 0.6862
# Epoch 4/25
# 854/854 [==============================] - 0s 233us/step - loss: 0.5765 - acc: 0.6932
# Epoch 5/25
# 854/854 [==============================] - 0s 234us/step - loss: 0.5747 - acc: 0.6874
# Epoch 6/25
# 854/854 [==============================] - 0s 246us/step - loss: 0.5737 - acc: 0.6885
# Epoch 7/25
# 854/854 [==============================] - 0s 239us/step - loss: 0.5730 - acc: 0.6909
# Epoch 8/25
# 854/854 [==============================] - 0s 230us/step - loss: 0.5726 - acc: 0.6897
# Epoch 9/25
# 854/854 [==============================] - 0s 231us/step - loss: 0.5714 - acc: 0.6909
# Epoch 10/25
# 854/854 [==============================] - 0s 231us/step - loss: 0.5707 - acc: 0.6920
# Epoch 11/25
# 854/854 [==============================] - 0s 244us/step - loss: 0.5702 - acc: 0.7014
# Epoch 12/25
# 854/854 [==============================] - 0s 233us/step - loss: 0.5697 - acc: 0.6991
# Epoch 13/25
# 854/854 [==============================] - 0s 238us/step - loss: 0.5689 - acc: 0.7026
# Epoch 14/25
# 854/854 [==============================] - 0s 233us/step - loss: 0.5687 - acc: 0.7037
# Epoch 15/25
# 854/854 [==============================] - 0s 235us/step - loss: 0.5680 - acc: 0.7108
# Epoch 16/25
# 854/854 [==============================] - 0s 235us/step - loss: 0.5672 - acc: 0.7108
# Epoch 17/25
# 854/854 [==============================] - 0s 232us/step - loss: 0.5665 - acc: 0.7155
# Epoch 18/25
# 854/854 [==============================] - 0s 237us/step - loss: 0.5671 - acc: 0.7096
# Epoch 19/25
# 854/854 [==============================] - 0s 233us/step - loss: 0.5659 - acc: 0.7155
# Epoch 20/25
# 854/854 [==============================] - 0s 246us/step - loss: 0.5668 - acc: 0.7178
# Epoch 21/25
# 854/854 [==============================] - 0s 232us/step - loss: 0.5649 - acc: 0.7237
# Epoch 22/25
# 854/854 [==============================] - 0s 244us/step - loss: 0.5647 - acc: 0.7166
# Epoch 23/25
# 854/854 [==============================] - 0s 231us/step - loss: 0.5638 - acc: 0.7131
# Epoch 24/25
# 854/854 [==============================] - 0s 232us/step - loss: 0.5636 - acc: 0.7190
# Epoch 25/25
# 854/854 [==============================] - 0s 237us/step - loss: 0.5636 - acc: 0.7131
# 212/212 [==============================] - 0s 296us/step
# Epoch 1/25
# 852/852 [==============================] - 0s 446us/step - loss: 0.6548 - acc: 0.6596
# Epoch 2/25
# 852/852 [==============================] - 0s 235us/step - loss: 0.5810 - acc: 0.6948
# Epoch 3/25
# 852/852 [==============================] - 0s 238us/step - loss: 0.5714 - acc: 0.6960
# Epoch 4/25
# 852/852 [==============================] - 0s 249us/step - loss: 0.5690 - acc: 0.6925
# Epoch 5/25
# 852/852 [==============================] - 0s 257us/step - loss: 0.5681 - acc: 0.6972
# Epoch 6/25
# 852/852 [==============================] - 0s 248us/step - loss: 0.5663 - acc: 0.7066
# Epoch 7/25
# 852/852 [==============================] - 0s 235us/step - loss: 0.5661 - acc: 0.6948
# Epoch 8/25
# 852/852 [==============================] - 0s 243us/step - loss: 0.5653 - acc: 0.7066
# Epoch 9/25
# 852/852 [==============================] - 0s 254us/step - loss: 0.5646 - acc: 0.7054
# Epoch 10/25
# 852/852 [==============================] - 0s 238us/step - loss: 0.5634 - acc: 0.6995
# Epoch 11/25
# 852/852 [==============================] - 0s 238us/step - loss: 0.5628 - acc: 0.7054
# Epoch 12/25
# 852/852 [==============================] - 0s 247us/step - loss: 0.5626 - acc: 0.7066
# Epoch 13/25
# 852/852 [==============================] - 0s 235us/step - loss: 0.5610 - acc: 0.7124
# Epoch 14/25
# 852/852 [==============================] - 0s 229us/step - loss: 0.5594 - acc: 0.7101
# Epoch 15/25
# 852/852 [==============================] - 0s 230us/step - loss: 0.5600 - acc: 0.7031
# Epoch 16/25
# 852/852 [==============================] - 0s 239us/step - loss: 0.5580 - acc: 0.7077
# Epoch 17/25
# 852/852 [==============================] - 0s 235us/step - loss: 0.5571 - acc: 0.7171
# Epoch 18/25
# 852/852 [==============================] - 0s 245us/step - loss: 0.5571 - acc: 0.7113
# Epoch 19/25
# 852/852 [==============================] - 0s 235us/step - loss: 0.5562 - acc: 0.7113
# Epoch 20/25
# 852/852 [==============================] - 0s 240us/step - loss: 0.5558 - acc: 0.7207
# Epoch 21/25
# 852/852 [==============================] - 0s 241us/step - loss: 0.5553 - acc: 0.7148
# Epoch 22/25
# 852/852 [==============================] - 0s 236us/step - loss: 0.5542 - acc: 0.7195
# Epoch 23/25
# 852/852 [==============================] - 0s 240us/step - loss: 0.5540 - acc: 0.7254
# Epoch 24/25
# 852/852 [==============================] - 0s 240us/step - loss: 0.5535 - acc: 0.7218
# Epoch 25/25
# 852/852 [==============================] - 0s 242us/step - loss: 0.5533 - acc: 0.7160
# 214/214 [==============================] - 0s 328us/step
# Epoch 1/25
# 852/852 [==============================] - 0s 461us/step - loss: 0.6591 - acc: 0.6596
# Epoch 2/25
# 852/852 [==============================] - 0s 239us/step - loss: 0.5864 - acc: 0.6972
# Epoch 3/25
# 852/852 [==============================] - 0s 230us/step - loss: 0.5735 - acc: 0.7019
# Epoch 4/25
# 852/852 [==============================] - 0s 236us/step - loss: 0.5709 - acc: 0.6995
# Epoch 5/25
# 852/852 [==============================] - 0s 243us/step - loss: 0.5690 - acc: 0.7066
# Epoch 6/25
# 852/852 [==============================] - 0s 248us/step - loss: 0.5678 - acc: 0.7031
# Epoch 7/25
# 852/852 [==============================] - 0s 236us/step - loss: 0.5674 - acc: 0.7101
# Epoch 8/25
# 852/852 [==============================] - 0s 246us/step - loss: 0.5671 - acc: 0.7113
# Epoch 9/25
# 852/852 [==============================] - 0s 244us/step - loss: 0.5655 - acc: 0.7113
# Epoch 10/25
# 852/852 [==============================] - 0s 246us/step - loss: 0.5649 - acc: 0.7148
# Epoch 11/25
# 852/852 [==============================] - 0s 238us/step - loss: 0.5647 - acc: 0.7089
# Epoch 12/25
# 852/852 [==============================] - 0s 237us/step - loss: 0.5637 - acc: 0.7148
# Epoch 13/25
# 852/852 [==============================] - 0s 234us/step - loss: 0.5632 - acc: 0.7101
# Epoch 14/25
# 852/852 [==============================] - 0s 238us/step - loss: 0.5632 - acc: 0.7171
# Epoch 15/25
# 852/852 [==============================] - 0s 239us/step - loss: 0.5632 - acc: 0.7148
# Epoch 16/25
# 852/852 [==============================] - 0s 238us/step - loss: 0.5619 - acc: 0.7160
# Epoch 17/25
# 852/852 [==============================] - 0s 236us/step - loss: 0.5610 - acc: 0.7218
# Epoch 18/25
# 852/852 [==============================] - 0s 238us/step - loss: 0.5616 - acc: 0.7148
# Epoch 19/25
# 852/852 [==============================] - 0s 232us/step - loss: 0.5609 - acc: 0.7242
# Epoch 20/25
# 852/852 [==============================] - 0s 244us/step - loss: 0.5604 - acc: 0.7242
# Epoch 21/25
# 852/852 [==============================] - 0s 245us/step - loss: 0.5602 - acc: 0.7254
# Epoch 22/25
# 852/852 [==============================] - 0s 246us/step - loss: 0.5602 - acc: 0.7195
# Epoch 23/25
# 852/852 [==============================] - 0s 238us/step - loss: 0.5595 - acc: 0.7218
# Epoch 24/25
# 852/852 [==============================] - 0s 240us/step - loss: 0.5602 - acc: 0.7218
# Epoch 25/25
# 852/852 [==============================] - 0s 235us/step - loss: 0.5588 - acc: 0.7171
# 214/214 [==============================] - 0s 394us/step
# Epoch 1/25
# 852/852 [==============================] - 0s 491us/step - loss: 0.6554 - acc: 0.6491
# Epoch 2/25
# 852/852 [==============================] - 0s 245us/step - loss: 0.5735 - acc: 0.7031
# Epoch 3/25
# 852/852 [==============================] - 0s 243us/step - loss: 0.5580 - acc: 0.7124
# Epoch 4/25
# 852/852 [==============================] - 0s 239us/step - loss: 0.5556 - acc: 0.7113
# Epoch 5/25
# 852/852 [==============================] - 0s 235us/step - loss: 0.5540 - acc: 0.7089
# Epoch 6/25
# 852/852 [==============================] - 0s 246us/step - loss: 0.5523 - acc: 0.7171
# Epoch 7/25
# 852/852 [==============================] - 0s 237us/step - loss: 0.5515 - acc: 0.7195
# Epoch 8/25
# 852/852 [==============================] - 0s 243us/step - loss: 0.5505 - acc: 0.7136
# Epoch 9/25
# 852/852 [==============================] - 0s 248us/step - loss: 0.5498 - acc: 0.7171
# Epoch 10/25
# 852/852 [==============================] - 0s 235us/step - loss: 0.5489 - acc: 0.7230
# Epoch 11/25
# 852/852 [==============================] - 0s 237us/step - loss: 0.5485 - acc: 0.7254
# Epoch 12/25
# 852/852 [==============================] - 0s 235us/step - loss: 0.5474 - acc: 0.7300
# Epoch 13/25
# 852/852 [==============================] - 0s 250us/step - loss: 0.5466 - acc: 0.7218
# Epoch 14/25
# 852/852 [==============================] - 0s 241us/step - loss: 0.5457 - acc: 0.7300
# Epoch 15/25
# 852/852 [==============================] - 0s 238us/step - loss: 0.5452 - acc: 0.7324
# Epoch 16/25
# 852/852 [==============================] - 0s 243us/step - loss: 0.5442 - acc: 0.7371
# Epoch 17/25
# 852/852 [==============================] - 0s 251us/step - loss: 0.5443 - acc: 0.7277
# Epoch 18/25
# 852/852 [==============================] - 0s 244us/step - loss: 0.5435 - acc: 0.7371
# Epoch 19/25
# 852/852 [==============================] - 0s 249us/step - loss: 0.5421 - acc: 0.7300
# Epoch 20/25
# 852/852 [==============================] - 0s 240us/step - loss: 0.5422 - acc: 0.7347
# Epoch 21/25
# 852/852 [==============================] - 0s 244us/step - loss: 0.5411 - acc: 0.7336
# Epoch 22/25
# 852/852 [==============================] - 0s 245us/step - loss: 0.5406 - acc: 0.7336
# Epoch 23/25
# 852/852 [==============================] - 0s 260us/step - loss: 0.5407 - acc: 0.7371
# Epoch 24/25
# 852/852 [==============================] - 0s 240us/step - loss: 0.5389 - acc: 0.7312
# Epoch 25/25
# 852/852 [==============================] - 0s 243us/step - loss: 0.5394 - acc: 0.7347
# 214/214 [==============================] - 0s 414us/step
# Epoch 1/25
# 854/854 [==============================] - 0s 521us/step - loss: 0.6423 - acc: 0.6815
# Epoch 2/25
# 854/854 [==============================] - 0s 237us/step - loss: 0.5664 - acc: 0.7108
# Epoch 3/25
# 854/854 [==============================] - 0s 239us/step - loss: 0.5534 - acc: 0.7119
# Epoch 4/25
# 854/854 [==============================] - 0s 249us/step - loss: 0.5509 - acc: 0.7143
# Epoch 5/25
# 854/854 [==============================] - 0s 246us/step - loss: 0.5490 - acc: 0.7166
# Epoch 6/25
# 854/854 [==============================] - 0s 249us/step - loss: 0.5486 - acc: 0.7131
# Epoch 7/25
# 854/854 [==============================] - 0s 239us/step - loss: 0.5467 - acc: 0.7237
# Epoch 8/25
# 854/854 [==============================] - 0s 237us/step - loss: 0.5468 - acc: 0.7272
# Epoch 9/25
# 854/854 [==============================] - 0s 248us/step - loss: 0.5452 - acc: 0.7260
# Epoch 10/25
# 854/854 [==============================] - 0s 246us/step - loss: 0.5448 - acc: 0.7283
# Epoch 11/25
# 854/854 [==============================] - 0s 247us/step - loss: 0.5450 - acc: 0.7260
# Epoch 12/25
# 854/854 [==============================] - 0s 247us/step - loss: 0.5433 - acc: 0.7248
# Epoch 13/25
# 854/854 [==============================] - 0s 249us/step - loss: 0.5425 - acc: 0.7272
# Epoch 14/25
# 854/854 [==============================] - 0s 245us/step - loss: 0.5422 - acc: 0.7260
# Epoch 15/25
# 854/854 [==============================] - 0s 248us/step - loss: 0.5413 - acc: 0.7319
# Epoch 16/25
# 854/854 [==============================] - 0s 241us/step - loss: 0.5402 - acc: 0.7248
# Epoch 17/25
# 854/854 [==============================] - 0s 247us/step - loss: 0.5402 - acc: 0.7272
# Epoch 18/25
# 854/854 [==============================] - 0s 252us/step - loss: 0.5392 - acc: 0.7354
# Epoch 19/25
# 854/854 [==============================] - 0s 245us/step - loss: 0.5397 - acc: 0.7283
# Epoch 20/25
# 854/854 [==============================] - 0s 241us/step - loss: 0.5384 - acc: 0.7342
# Epoch 21/25
# 854/854 [==============================] - 0s 241us/step - loss: 0.5388 - acc: 0.7342
# Epoch 22/25
# 854/854 [==============================] - 0s 239us/step - loss: 0.5379 - acc: 0.7319
# Epoch 23/25
# 854/854 [==============================] - 0s 238us/step - loss: 0.5376 - acc: 0.7319
# Epoch 24/25
# 854/854 [==============================] - 0s 247us/step - loss: 0.5372 - acc: 0.7330
# Epoch 25/25
# 854/854 [==============================] - 0s 246us/step - loss: 0.5366 - acc: 0.7248
# 212/212 [==============================] - 0s 459us/step
# Epoch 1/25
# 854/854 [==============================] - 0s 543us/step - loss: 0.6548 - acc: 0.6616
# Epoch 2/25
# 854/854 [==============================] - 0s 249us/step - loss: 0.5899 - acc: 0.6862
# Epoch 3/25
# 854/854 [==============================] - 0s 243us/step - loss: 0.5781 - acc: 0.6920
# Epoch 4/25
# 854/854 [==============================] - 0s 248us/step - loss: 0.5765 - acc: 0.6967
# Epoch 5/25
# 854/854 [==============================] - 0s 248us/step - loss: 0.5737 - acc: 0.6920
# Epoch 6/25
# 854/854 [==============================] - 0s 246us/step - loss: 0.5734 - acc: 0.6920
# Epoch 7/25
# 854/854 [==============================] - 0s 245us/step - loss: 0.5729 - acc: 0.6956
# Epoch 8/25
# 854/854 [==============================] - 0s 244us/step - loss: 0.5726 - acc: 0.6979
# Epoch 9/25
# 854/854 [==============================] - 0s 250us/step - loss: 0.5712 - acc: 0.7002
# Epoch 10/25
# 854/854 [==============================] - 0s 249us/step - loss: 0.5719 - acc: 0.7037
# Epoch 11/25
# 854/854 [==============================] - 0s 244us/step - loss: 0.5700 - acc: 0.7096
# Epoch 12/25
# 854/854 [==============================] - 0s 246us/step - loss: 0.5700 - acc: 0.7084
# Epoch 13/25
# 854/854 [==============================] - 0s 238us/step - loss: 0.5692 - acc: 0.7073
# Epoch 14/25
# 854/854 [==============================] - 0s 246us/step - loss: 0.5687 - acc: 0.7037
# Epoch 15/25
# 854/854 [==============================] - 0s 251us/step - loss: 0.5681 - acc: 0.7131
# Epoch 16/25
# 854/854 [==============================] - 0s 243us/step - loss: 0.5676 - acc: 0.7119
# Epoch 17/25
# 854/854 [==============================] - 0s 243us/step - loss: 0.5669 - acc: 0.7190
# Epoch 18/25
# 854/854 [==============================] - 0s 248us/step - loss: 0.5658 - acc: 0.7166
# Epoch 19/25
# 854/854 [==============================] - 0s 247us/step - loss: 0.5659 - acc: 0.7131
# Epoch 20/25
# 854/854 [==============================] - 0s 251us/step - loss: 0.5651 - acc: 0.7178
# Epoch 21/25
# 854/854 [==============================] - 0s 247us/step - loss: 0.5650 - acc: 0.7073
# Epoch 22/25
# 854/854 [==============================] - 0s 245us/step - loss: 0.5638 - acc: 0.7131
# Epoch 23/25
# 854/854 [==============================] - 0s 247us/step - loss: 0.5635 - acc: 0.7190
# Epoch 24/25
# 854/854 [==============================] - 0s 245us/step - loss: 0.5621 - acc: 0.7201
# Epoch 25/25
# 854/854 [==============================] - 0s 246us/step - loss: 0.5619 - acc: 0.7096
# 212/212 [==============================] - 0s 511us/step

# %%
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot((results))
names = [i.__name__ for i in model]
ax.set_xticklabels(names)
plt.show()

# %% [raw]
# ### Extract the data desired for the submission

# %%
df_sample_sub = pd.read_csv(data_dir + 'SampleSubmissionStage1.csv')
n_test_games = len(df_sample_sub)

def get_year_t1_t2(ID):
    """Return a tuple with ints `year`, `team1` and `team2`."""
    return (int(x) for x in ID.split('_'))

# %%
X_test = np.zeros(shape=(n_test_games, xDim))
for ii, row in df_sample_sub.iterrows():
    year, t1, t2 = get_year_t1_t2(row.ID)
    t1_seed = df_seeds[(df_seeds.TeamID == t1) & (df_seeds.Season == year)].seed_int.values[0]
    t2_seed = df_seeds[(df_seeds.TeamID == t2) & (df_seeds.Season == year)].seed_int.values[0]
    diff_seed = t1_seed - t2_seed
    X_test[ii, 0] = t1_seed
    X_test[ii, 1] = diff_seed
    X_test[ii, 2] = t1
    X_test[ii, 3] = year

# %% [markdown]
# ### Scale data with appropriate scaler

# %%
X_test = scaler.fit_transform(X_test)

# %% [markdown]
# ## Make Predictions ##
# Create predictions using the logistic regression model we trained.

# %%
preds = base2.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-efa0e092d698> in <module>()
# ----> 1 preds = base2.predict(X_test)
#
# NameError: name 'base2' is not defined

# %%
clipped_preds = np.clip(preds, 0.05, 0.95)
df_sample_sub.Pred = clipped_preds
df_sample_sub.head()

# %% [markdown]
# Lastly, create your submission file!

# %%
filename = 'KerasMLP_RankSeedsYear'
c=0
ext = '.csv'
if os.path.exists(filename+ext):
    while os.path.exists(filename+ext):
        c+=1
        filename = filename+'_'+str(c)
    df_sample_sub.to_csv(filename+ext, index=False)
else:
    df_sample_sub.to_csv(filename+ext, index=False)
